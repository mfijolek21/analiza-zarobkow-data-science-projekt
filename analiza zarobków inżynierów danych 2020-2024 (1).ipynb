# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("salaries.csv")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\diego'

# %%
dataset.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
dataset.tail()
# Out:
#        work_year experience_level employment_type                 job_title  \
# 16529       2020               SE              FT            Data Scientist
# 16530       2021               MI              FT  Principal Data Scientist
# 16531       2020               EN              FT            Data Scientist
# 16532       2020               EN              CT     Business Data Analyst
# 16533       2021               SE              FT      Data Science Manager
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 16529   412000             USD         412000                 US
# 16530   151000             USD         151000                 US
# 16531   105000             USD         105000                 US
# 16532   100000             USD         100000                 US
# 16533  7000000             INR          94665                 IN
#
#        remote_ratio company_location company_size
# 16529           100               US            L
# ...

# %%
dataset.duplicated().sum()
# Out:
# 6421

# %%
dataset.loc[dataset.duplicated(keep='first'), :]
# Out:
#        work_year experience_level employment_type                  job_title  \
# 62          2024               SE              FT  Machine Learning Engineer
# 151         2024               SE              FT           Research Analyst
# 238         2024               MI              FT               Data Analyst
# 239         2024               MI              FT               Data Analyst
# 247         2024               SE              FT             Data Scientist
# ...          ...              ...             ...                        ...
# 16235       2022               MI              FT             Data Scientist
# 16236       2022               SE              FT              Data Engineer
# 16237       2022               SE              FT              Data Engineer
# 16376       2021               MI              FT              Data Engineer
# 16490       2021               MI              FT             Data Scientist
#
# ...

# %%
dataset.drop_duplicates(keep='first',inplace= True)

# %%
plt.hist(dataset['salary_in_usd'])
# Out:
# (array([2.415e+03, 4.519e+03, 2.460e+03, 5.690e+02, 1.020e+02, 2.300e+01,
#         4.000e+00, 3.000e+00, 9.000e+00, 9.000e+00]),
#  array([ 15000.,  93500., 172000., 250500., 329000., 407500., 486000.,
#         564500., 643000., 721500., 800000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(dataset['salary_in_usd'])
plt.xlabel('roczne zarobi w dolarach amerykańskich')
plt.ylabel('ilość')
# Out:
# Text(0, 0.5, 'ilość')

# %%
sns.countplot(dataset['experience_level'])
plt.ylabel('poziom doświadczenia')
plt.xlabel('ilość')
# Out:
# Text(0.5, 0, 'ilość')

# %%
dataset['salary_in_usd'].describe()
# Out:
# count     10113.000000
# mean     146662.179571
# std       72697.319441
# min       15000.000000
# 25%       95000.000000
# 50%      138750.000000
# 75%      185900.000000
# max      800000.000000
# Name: salary_in_usd, dtype: float64

# %%
dataset['salary_in_usd'].skew() #skośność
# Out:
# 1.6425312492734645

# %%
sns.boxplot(x='experience_level', y='salary_in_usd',data=dataset)
plt.ylabel('roczne zarobki w dolarach amerykańskich')
plt.xlabel('poziom doświadczenia')
# Out:
# Text(0.5, 0, 'poziom doświadczenia')

# %%
sns.boxplot( y='salary_in_usd',data=dataset)
plt.ylabel('roczne zarobki w dolarach amerykańskich')
# Out:
# Text(0, 0.5, 'roczne zarobki w dolarach amerykańskich')

# %%
dataset['salary_in_usd'].median()
# Out:
# 138750.0

# %%
dataset['remote_ratio'].value_counts()
# Out:
# remote_ratio
# 0      6394
# 100    3472
# 50      247
# Name: count, dtype: int64

# %%
dataset['company_size'].value_counts()
# Out:
# company_size
# M    9284
# L     642
# S     187
# Name: count, dtype: int64

# %%
sns.boxplot(x='company_size', y="salary_in_usd", data=dataset)
plt.ylabel('roczne zarobki w dolarach amerykańskich')
plt.xlabel('rozmiar przedsiębiorstwa')
# Out:
# Text(0.5, 0, 'rozmiar przedsiębiorstwa')

# %%
sns.boxplot(x='work_year', y="salary_in_usd", data=dataset)
plt.ylabel('roczne zarobki w dolarach amerykańskich')
plt.xlabel('rok')
# Out:
# Text(0.5, 0, 'rok')

# %%
dataset.groupby('work_year')['salary_in_usd'].describe()
# Out:
#             count           mean           std      min       25%       50%  \
# work_year
# 2020         75.0  102250.866667  82722.309481  15000.0   47899.0   79833.0
# 2021        216.0   99501.287037  67032.458991  15000.0   53868.5   82636.0
# 2022       1116.0  131650.319892  61530.340461  15000.0   85000.0  130000.0
# 2023       4632.0  150644.881261  70007.702690  15680.0  100400.0  143000.0
# 2024       4074.0  149564.232204  76862.377005  16666.0   96200.0  139350.0
#
#                 75%       max
# work_year
# 2020       117552.0  450000.0
# 2021       136250.0  423000.0
# 2022       172200.0  430967.0
# 2023       190000.0  750000.0
# 2024       187942.5  800000.0
